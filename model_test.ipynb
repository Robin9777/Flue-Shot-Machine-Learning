# %%
from PipelinesModels import *

# %%
df = pd.read_csv("training_set_features.csv", index_col="respondent_id")
results = pd.read_csv("training_set_labels.csv", index_col="respondent_id")

model_builder = FlueShotModel("random_forest", df, results)

model_builder.print_classification_report("h1n1_vaccine", set_="test")
model_builder.print_classification_report("seasonal_vaccine", set_="test")
# Out:
# Classification Report for test set
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       2 results = pd.read_csv("training_set_labels.csv", index_col="respondent_id")
#       4 model_builder = FlueShotModel("random_forest", df, results)
# ----> 6 model_builder.print_classification_report("h1n1_vaccine", set_="test")
#       7 model_builder.print_classification_report("seasonal_vaccine", set_="test")
#
# File c:\SandBox\FluShotLearning\PipelinesModels.py:211, in FlueShotModel.print_classification_report(self, label, set_)
#     208     y_pred = model.predict(self.X_test)
#     210 print(f"\nClassification Report for {set_} set")
# --> 211 print(classification_report(self.y_test, y_pred))
#
# File c:\SandBox\FluShotLearning\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\SandBox\FluShotLearning\.venv\Lib\site-packages\sklearn\metrics\_classification.py:2948, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2840 """Build a text report showing the main classification metrics.
#    2841
#    2842 Read more in the :ref:`User Guide <classification_report>`.
#    (...)   2944 <BLANKLINE>
#    2945 """
#    2947 y_true, y_pred = attach_unique(y_true, y_pred)
# -> 2948 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2950 if labels is None:
#    2951     labels = unique_labels(y_true, y_pred)
#
# File c:\SandBox\FluShotLearning\.venv\Lib\site-packages\sklearn\metrics\_classification.py:106, in _check_targets(y_true, y_pred)
#     103     y_type = {"multiclass"}
#     105 if len(y_type) > 1:
# --> 106     raise ValueError(
#     107         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#     108             type_true, type_pred
#     109         )
#     110     )
#     112 # We can't have more than one value on y_type => The set is no more needed
#     113 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets
